# %%
import datajoint as dj
dj.conn()
# Out:
# [2024-11-12 20:23:29,430][INFO]: Connecting root@localhost:3306
# [2024-11-12 20:23:29,495][INFO]: Connected root@localhost:3306
# DataJoint connection (connected) root@localhost:3306

# %%
schema = dj.Schema('assignment2')

# %%
@schema
class PetsTreated(dj.Manual):
    definition = """
    petid : Varchar(15)
    ---
    pet_name: varchar(15)
    pet_species: varchar(15)
    date_of_birth: date
    sex: char(1)
    """

# %%
PetsTreated()
# Out:
# *petid    pet_name     pet_species    date_of_birth  sex
# +-------+ +----------+ +------------+ +------------+ +-----+
#
#  (Total: 0)

# %%
PetsTreated.insert1(
    {'petid': 543210678,
    "pet_name": "Scoobydoo", 
    "pet_species": "dog", 
    "date_of_birth": "2017-11-10", 
    "sex": "M"})

# %%
PetsTreated()
# Out:
# *petid        pet_name      pet_species    date_of_birth  sex
# +-----------+ +-----------+ +------------+ +------------+ +-----+
# 543210678     Scoobydoo     dog            2017-11-10     M
#  (Total: 1)

# %%
PetsTreated.insert1(
    {'petid': 432106785,
    "pet_name": "Garfield", 
    "pet_species": "cat", 
    "date_of_birth": "2006-07-12", 
    "sex": "M"})

# %%
PetsTreated.insert1(
    {'petid': 453210699,
    "pet_name": "CuriousGeorge", 
    "pet_species": "monkey", 
    "date_of_birth": "1985-01-02", 
    "sex": "F"})

# %%
PetsTreated()
# Out:
# *petid        pet_name       pet_species    date_of_birth  sex
# +-----------+ +------------+ +------------+ +------------+ +-----+
# 432106785     Garfield       cat            2006-07-12     M
# 453210699     CuriousGeorge  monkey         1985-01-02     F
# 543210678     Scoobydoo      dog            2017-11-10     M
#  (Total: 3)

# %%
schema = dj.Schema('vets')

# %%
@schema
class Vets(dj.Manual):
    definition = """
    vet_id: int
    ---
    vet_name: varchar(60)
    highest_degree_attained: varchar(60)
    date_of_birth: date
    hire_date: date 
    """

# %%
Vets()
# Out:
# *vet_id    vet_name     highest_degree date_of_birth  hire_date
# +--------+ +----------+ +------------+ +------------+ +-----------+
#
#  (Total: 0)

# %%
Vets.insert1(
    {'vet_id': 432106785,
    "vet_name": "John Rambo", 
    "highest_degree_attained": "masters",
    "date_of_birth": "1969-07-08", 
    "hire_date": "2010-03-08"})

# %%
Vets()
# Out:
# *vet_id       vet_name       highest_degree date_of_birth  hire_date
# +-----------+ +------------+ +------------+ +------------+ +------------+
# 432106785     John Rambo     masters        1969-07-08     2010-03-08
#  (Total: 1)

# %%
Vets.insert1(
    {'vet_id': 817106123,
    "vet_name": "Chuck Norris", 
    "highest_degree_attained": "doctorate",
    "date_of_birth": "1965-01-01", 
    "hire_date": "1990-08-27"})

# %%
Vets()
# Out:
# *vet_id       vet_name       highest_degree date_of_birth  hire_date
# +-----------+ +------------+ +------------+ +------------+ +------------+
# 432106785     John Rambo     masters        1969-07-08     2010-03-08
# 817106123     Chuck Norris   doctorate      1965-01-01     1990-08-27
#  (Total: 2)

# %%
Vets.insert1(
    {'vet_id': 435106227,
    "vet_name": "Tyra Banks", 
    "highest_degree_attained": "bachelors",
    "date_of_birth": "1973-12-04", 
    "hire_date": "1984-06-13"})

# %%
Vets()
# Out:
# *vet_id       vet_name       highest_degree date_of_birth  hire_date
# +-----------+ +------------+ +------------+ +------------+ +------------+
# 432106785     John Rambo     masters        1969-07-08     2010-03-08
# 435106227     Tyra Banks     bachelors      1973-12-04     1984-06-13
# 817106123     Chuck Norris   doctorate      1965-01-01     1990-08-27
#  (Total: 3)

# %%
schema = dj.Schema('states')

# %%
@schema
class States(dj.Manual):
    definition = """
    state : char(2)
    territory : char(2)
    capital : varchar(60)
    ---
    year_of_acceptance : int(4)
    """

# %%
States()
# Out:
# *state    *territory    *capital    year_of_accept
# +-------+ +-----------+ +---------+ +------------+
#
#  (Total: 0)

# %%
States.insert1(
    dict(
        state = "TX",
        territory = " ", 
        capital = "Austin",
        year_of_acceptance = "1845", 
    )
)

# %%
States()
# Out:
# *state    *territory    *capital    year_of_accept
# +-------+ +-----------+ +---------+ +------------+
# TX                      Austin      1845
#  (Total: 1)

# %%
States.insert1(
    dict(
        state = "DE",
        territory = " ", 
        capital = "Dover",
        year_of_acceptance = "1787", 
    )
)

# %%
States.insert1(
    dict(
        state = "AL",
        territory = " ", 
        capital = "Montgomery",
        year_of_acceptance = "1819", 
    )
)

# %%
States()
# Out:
# *state    *territory    *capital       year_of_accept
# +-------+ +-----------+ +------------+ +------------+
# AL                      Montgomery     1819
# DE                      Dover          1787
# TX                      Austin         1845
#  (Total: 3)

# %%
States.insert1(
    dict(
        state = " ",
        territory = "PR ", 
        capital = "Providence",
        year_of_acceptance = "1790", 
    )
)

# %%
States()
# Out:
# *state    *territory    *capital       year_of_accept
# +-------+ +-----------+ +------------+ +------------+
#           PR            Providence     1790
# AL                      Montgomery     1819
# DE                      Dover          1787
# TX                      Austin         1845
#  (Total: 4)

# %%
schema = dj.Schema('representative')

# %%
@schema
class Representative(dj.Manual):
    definition = """
    state : char(2)
    district : tinyint unsigned
    ---
    full_name : varchar(60)
    party     : varchar(20)
    phone     : varchar(15)
    """

# %%
Representative()
# Out:
# *state    *district    full_name     party     phone
# +-------+ +----------+ +-----------+ +-------+ +-------+
#
#  (Total: 0)

# %%
Representative.insert1(
    dict(
        state = "TX",
        district = 1, 
        full_name = "Nathaniel Moran",
        party = "Republican", 
        phone = "(202) 225-3035"
    )
)

# %%
Representative()
# Out:
# *state    *district    full_name      party          phone
# +-------+ +----------+ +------------+ +------------+ +------------+
# TX        1            Nathaniel Mora Republican     (202) 225-3035
#  (Total: 1)

# %%
Representative.insert1(
    dict(
        state = "TX",
        district = 7, 
        full_name = "Lizzie Fletcher",
        party = "Democratic", 
        phone = "(202) 225-2571"
    )
)

# %%
Representative.insert1(
    dict(
        state = "TX",
        district = 29, 
        full_name = "Sylvia Garcia",
        party = "Democratic", 
        phone = "(202) 225-1688"
    )
)

# %%
Representative()
# Out:
# *state    *district    full_name      party          phone
# +-------+ +----------+ +------------+ +------------+ +------------+
# TX        1            Nathaniel Mora Republican     (202) 225-3035
# TX        7            Lizzie Fletche Democratic     (202) 225-2571
# TX        29           Sylvia Garcia  Democratic     (202) 225-1688
#  (Total: 3)

# %%
schema = dj.Schema('governor')

# %%
@schema
class Governor(dj.Manual):
    definition = """
    state : char(2)
    governor_full_name : varchar(60)
    ---
    date_of_appointment : date
    """

# %%
Governor()
# Out:
# *state    *governor_full date_of_appoin
# +-------+ +------------+ +------------+
#
#  (Total: 0)

# %%
Governor.insert1(
    dict(
        state = "TX",
        governor_full_name = "Greg Abbott",
        date_of_appointment = "2015-01-20"
    )
)

# %%
Governor.insert1(
    dict(
           state = "IN",
       governor_full_name = "Eric Holcomb",
       date_of_appointment = "2017-01-09"
    )
)

# %%
Governor.insert1(
    dict(
           state = "LA",
       governor_full_name = "Jeff Landry",
       date_of_appointment = "2024-01-08"
    )
)

# %%
Governor()
# Out:
# *state    *governor_full date_of_appoin
# +-------+ +------------+ +------------+
# IN        Eric Holcomb   2017-01-09
# LA        Jeff Landry    2024-01-08
# TX        Greg Abbott    2015-01-20
#  (Total: 3)

# %%
schema = dj.Schema('homework')

# %%
@schema
class Homework(dj.Manual):
    definition = """
    course_name : varchar(60)
    course_id : varchar (8)
    ---
    homework_number : int unsigned
    due_date : date
    """

# %%
Homework()
# Out:
# *course_name   *course_id    homework_numbe due_date
# +------------+ +-----------+ +------------+ +----------+
#
#  (Total: 0)

# %%
Homework.insert1(
    dict(
        course_name = "Statistical Models",
       course_id = "MSDS5350",
       homework_number = "1",
       due_date = "2024-09-13"
    )
)

# %%
Homework.insert1(
    dict(
         course_name = "Databases and Data Management",
       course_id = "MSDS5315",
       homework_number = "1",
       due_date = "2024-09-10"
    )
)

# %%
Homework.insert1(
    dict(
         course_name = "Introduction to Analytics",
       course_id = "MSDS5311",
       homework_number = "1",
       due_date = "2024-09-09"
    )
)

# %%
Homework()
# Out:
# *course_name   *course_id    homework_numbe due_date
# +------------+ +-----------+ +------------+ +------------+
# Databases and  MSDS5315      1              2024-09-10
# Introduction t MSDS5311      1              2024-09-09
# Statistical Mo MSDS5350      1              2024-09-13
#  (Total: 3)

# %%
schema = dj.Schema('student')

# %%
@schema
class Student(dj.Manual):
    definition = """
    student_full_name : varchar(60)
    student_github : varchar (60)
    ---
    student_email : varchar(60)
    """

# %%
Student.insert1(
    dict(
        student_full_name = "Katarina Barbosa",
       student_github = "katarinatmb",
       student_email = "katarinaB@databaseclass.com"
    )
)

# %%
Student.insert1(
    dict(
         student_full_name = "Edgar Serrano",
         student_github = "edgarser3",
        student_email = "edgar_ser@databaseclass365.com"
    )
)

# %%
Student.insert1(
    dict(
         student_full_name = "Salman Shareef",
         student_github = "Salmanshareef2000",
         student_email = "SalmanSha@databaseclass247.com"
    )
)

# %%
Student()
# Out:
# *student_full_ *student_githu student_email
# +------------+ +------------+ +------------+
# Edgar Serrano  edgarser3      edgar_ser@data
# Katarina Barbo katarinatmb    katarinaB@data
# Salman Shareef Salmanshareef2 SalmanSha@data
#  (Total: 3)

# %%
schema = dj.Schema('champion')

# %%
@schema 
class Champion(dj.Manual):
    definition = """
    athlete_name : varchar(60)
    ---
    nationality : varchar(60)
    finish_time : time
    """

# %%
Champion.insert1(
    dict(
         athlete_name = "Ben Johnson",
         nationality = "American",
         finish_time = 10.3
    )
)

# %%
Champion.insert1(
    dict(
         athlete_name = "Carl Lewis",
         nationality = "Canadian",
         finish_time = 10.8
    )
)

# %%
Champion.insert1(
    dict(
         athlete_name = "Ussain Bolt",
         nationality = "Jamaican",
         finish_time = 9.8
    )
)

# %%
Champion()
# Out:
# *athlete_name  nationality    finish_time
# +------------+ +------------+ +------------+
# Ben Johnson    American       0:00:10
# Carl Lewis     Canadian       0:00:11
# Ussain Bolt    Jamaican       0:00:10
#  (Total: 3)
